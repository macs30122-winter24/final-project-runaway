# %%
# test government trust and democarcy

# %%
#trust

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
trust = pd.read_csv(r'test\datatables_trust.csv')

# %%
trust
# Out:
#     調查開始日期Survey Start Date 調查結束日期Survey End Date 樣本數目Sample size  \
# 0                2024-01-02            2024-01-11             669
# 1                2023-11-01            2023-11-15           1,004
# 2                2023-08-01            2023-08-10           1,005
# 3                2023-05-03            2023-05-18           1,003
# 4                2023-02-01            2023-02-09           1,017
# ..                      ...                   ...             ...
# 349              1993-04-06            1993-04-13             721
# 350              1993-03-03            1993-03-04             577
# 351              1993-02-03            1993-02-04             718
# 352              1993-01-19            1993-01-20             699
# 353              1992-12-08            1992-12-10             640
#
#     次樣本數目Subsample size 回應比率Response rate 好信任Very trust 幾信任Quite trust  \
# 0                   335             50.4%         23.8%          27.9%
# 1                   518             51.4%         23.3%          30.5%
# 2                   520             54.5%         16.5%          31.6%
# 3                   514             52.4%         23.2%          28.7%
# 4                   504             58.0%         21.0%          32.4%
# ..                  ...               ...           ...            ...
# 349                 721             62.5%         10.2%          39.6%
# 350                 577             64.5%          7.2%          52.4%
# 351                 718             66.5%          6.4%          44.3%
# 352                 699             61.0%          8.0%          44.7%
# 353                 640             65.2%          9.7%          47.2%
#
#     一半半Half-half 幾唔信任Quite distrust 好唔信任Very distrust 唔知/難講DK/HS 合計Total  \
# 0          12.4%               7.9%             27.1%       0.9%  100.0%
# 1          10.8%              12.1%             20.6%       2.7%  100.0%
# 2          13.4%              16.1%             21.7%       0.7%  100.0%
# 3          13.6%              12.8%             19.6%       2.1%  100.0%
# 4          15.2%              11.5%             17.5%       2.3%  100.0%
# ..           ...                ...               ...        ...     ...
# 349        13.8%              17.7%              5.9%      12.8%  100.0%
# 350        19.6%              12.5%              2.1%       6.3%  100.0%
# 351        15.7%              20.3%              4.7%       8.6%  100.0%
# 352        18.3%              19.7%              3.7%       5.5%  100.0%
# 353        14.7%              20.2%              3.6%       4.6%  100.0%
#
#     信任Trust 不信任Distrust 淨值Net Value  平均量值Mean value 基數Base  \
# 0     51.7%       35.0%       16.7%             3.1    331
# 1     53.8%       32.7%       21.2%             3.2    504
# 2     48.1%       37.8%       10.2%             3.1    516
# 3     51.9%       32.4%       19.5%             3.2    503
# 4     53.5%       29.0%       24.4%             3.3    474
# ..      ...         ...         ...             ...    ...
# 349   49.8%       23.6%       26.2%             2.9    629
# 350   59.6%       14.6%       45.0%             3.3    541
# 351   50.7%       25.0%       25.7%             3.0    656
# 352   52.7%       23.4%       29.3%             3.2    660
# 353   56.9%       23.8%       33.1%             3.3    611
#
#      樣本平均標準誤差Standard Error of Mean 備註Remark
# 0                               0.1        $
# 1                               0.1      NaN
# 2                               0.1      NaN
# 3                               0.1      NaN
# 4                               0.1      NaN
# ..                              ...      ...
# 349                             0.1      NaN
# 350                             0.1      NaN
# 351                             0.1      NaN
# 352                             0.1      NaN
# 353                             0.1      NaN
#
# [354 rows x 19 columns]

# %%
trust.columns = ['Survey Start Date', 'Survey End Date', 'Sample size',
       'Subsample size', 'Response rate', 'Very trust',
       'Quite trust', 'Half-half', 'Quite distrust',
       'Very distrust', 'DK/HS', 'Total', 'Trust', 'Distrust',
       'Net Value', 'Mean value', 'Base',
       'Standard Error of Mean', 'Remark']

# %%
trust['Survey Start Date'] = pd.to_datetime(trust['Survey Start Date'])

# %%
trust['Net Value'] = trust['Net Value'].str.rstrip('%').astype(float)
trust['Very trust'] = trust['Very trust'].str.rstrip('%').astype(float)
trust['Quite trust'] = trust['Quite trust'].str.rstrip('%').astype(float)
trust['Very distrust'] = trust['Very distrust'].str.rstrip('%').astype(float)
trust['Quite distrust'] = trust['Quite distrust'].str.rstrip('%').astype(float)

# %%
recent = trust[trust['Survey Start Date'] >= pd.to_datetime('2017-01-01')]

# %%
recent
# Out:
#    Survey Start Date  Net Value  Very trust  Quite trust  Very distrust  \
# 0         2024-01-02       16.7        23.8         27.9           27.1
# 1         2023-11-01       21.2        23.3         30.5           20.6
# 2         2023-08-01       10.2        16.5         31.6           21.7
# 3         2023-05-03       19.5        23.2         28.7           19.6
# 4         2023-02-01       24.4        21.0         32.4           17.5
# ..               ...        ...         ...          ...            ...
# 82        2017-03-06        8.5        10.3         33.2           17.5
# 83        2017-02-20       10.1        11.1         34.8           14.1
# 84        2017-02-06        2.6         8.3         34.0           20.7
# 85        2017-01-19       10.6        11.5         36.0           20.7
# 86        2017-01-03        2.7        10.0         31.9           19.8
#
#     Quite distrust  trust  distrust
# 0              7.9   51.7     -35.0
# 1             12.1   53.8     -32.7
# 2             16.1   48.1     -37.8
# 3             12.8   51.9     -32.4
# 4             11.5   53.4     -29.0
# ..             ...    ...       ...
# 82            17.5   43.5     -35.0
# 83            21.7   45.9     -35.8
# 84            19.0   42.3     -39.7
# 85            16.2   47.5     -36.9
# 86            19.4   41.9     -39.2
#
# [87 rows x 8 columns]

# %%
recent = recent[['Survey Start Date', 'Net Value', 'Very trust', 'Quite trust', 'Very distrust', 'Quite distrust']]

# %%
recent['trust'] = recent['Quite trust'] + recent['Very trust']
recent['distrust'] = -recent['Quite distrust'] - recent['Very distrust']
# Out:
# C:\Users\Annii\AppData\Local\Temp\ipykernel_24164\3643793328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent['trust'] = recent['Quite trust'] + recent['Very trust']
# C:\Users\Annii\AppData\Local\Temp\ipykernel_24164\3643793328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent['distrust'] = -recent['Quite distrust'] - recent['Very distrust']

# %%
plt.figure(figsize=(10, 6))
plt.plot(recent['Survey Start Date'], recent['trust'], marker='o', linestyle='-', label='Trust')
plt.plot(recent['Survey Start Date'], recent['Net Value'], marker='s', linestyle='-', label='Net Value')
plt.plot(recent['Survey Start Date'], recent['distrust'], marker='^', linestyle='-', label='Distrust')
plt.title('On the whole, do you trust the HKSAR Government')
plt.xlabel('Date')
plt.ylabel('Value (Unit: %)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#democracy

# %%
democracy = pd.read_csv(r'test\datatables_democracy.csv')

# %%
democracy.columns = ['Survey Start Date', 'Survey End Date',
       'Successful cases', 'Subsample', 'Response rate',
       'Very satisfied', 'Quite satisfied', 'Satisfied',
       'Half-half', 'Quite dissatisfied', 'Very dissatisfied',
       'Dissatisfied', 'DK/HS', 'Total', 'Netvalue',
       'Mean value', 'Base', 'Standard Error of Mean',
       'Remark']

# %%
democracy['Survey Start Date'] = pd.to_datetime(democracy['Survey Start Date'])

# %%
democracy['Net Value'] = democracy['Netvalue'].str.rstrip('%').astype(float)
democracy['Very satisfied'] = democracy['Very satisfied'].str.rstrip('%').astype(float)
democracy['Quite satisfied'] = democracy['Quite satisfied'].str.rstrip('%').astype(float)
democracy['Very dissatisfied'] = democracy['Very dissatisfied'].str.rstrip('%').astype(float)
democracy['Quite dissatisfied'] = democracy['Quite dissatisfied'].str.rstrip('%').astype(float)

# %%
recent = democracy[democracy['Survey Start Date'] >= pd.to_datetime('2017-01-01')]

# %%
recent['trust'] = recent['Quite satisfied'] + recent['Very satisfied']
recent['distrust'] = -recent['Quite dissatisfied'] - recent['Very dissatisfied']
# Out:
# C:\Users\Annii\AppData\Local\Temp\ipykernel_24164\3350052659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent['trust'] = recent['Quite satisfied'] + recent['Very satisfied']
# C:\Users\Annii\AppData\Local\Temp\ipykernel_24164\3350052659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent['distrust'] = -recent['Quite dissatisfied'] - recent['Very dissatisfied']

# %%
plt.figure(figsize=(10, 6))
plt.plot(recent['Survey Start Date'], recent['trust'], marker='o', linestyle='-', label='Trust')
plt.plot(recent['Survey Start Date'], recent['Net Value'], marker='s', linestyle='-', label='Net Value')
plt.plot(recent['Survey Start Date'], recent['distrust'], marker='^', linestyle='-', label='Distrust')
plt.title("Are you satisfied with the HKSAR Government's performance on the pace of democratic development")
plt.xlabel('Date')
plt.ylabel('Value (Unit: %)')
plt.legend()
plt.grid(True)
plt.show()
